# %%
import pandas as pd

# %%
df = pd.read_csv('./dim_place.csv')

# %%
df
# Out:
#            Country           City         State  Postal_Code   Region
# 0    United States           Troy      New York        12180     East
# 1    United States        Atlanta       Georgia        30318    South
# 2    United States       Columbus       Indiana        47201  Central
# 3    United States          Salem        Oregon        97301     West
# 4    United States        Phoenix       Arizona        85023     West
# ..             ...            ...           ...          ...      ...
# 795  United States  New York City      New York        10035     East
# 796  United States   Philadelphia  Pennsylvania        19134     East
# 797  United States       Amarillo         Texas        79109  Central
# 798  United States    San Antonio         Texas        78207  Central
# 799  United States        Seattle    Washington        98115     West
#
# [800 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Country', 'City', 'State', 'Postal_Code', 'Region'], dtype='object')

# %%
dim_place = 'dim_place'

# %%
for indice, fila in df.iterrows():
    valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
    comando_sql = f"INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ({valores});"
    print(comando_sql)
# Out:
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Troy', 'New York', 12180, 'East');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Atlanta', 'Georgia', 30318, 'South');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Columbus', 'Indiana', 47201, 'Central');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Salem', 'Oregon', 97301, 'West');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Phoenix', 'Arizona', 85023, 'West');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Roseville', 'California', 95661, 'West');
# INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ('United States', 'Denver', 'Colorado', 80219, 'West');
# ...

# %%
with open('insert_dim_place.sql', 'w') as archivo_sql:
    for indice, fila in df.iterrows():
        valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
        comando_sql = f"INSERT INTO dim_place (Country, City, State, Postal_Code, Region) VALUES ({valores});\n"
        archivo_sql.write(comando_sql)
