# %% [markdown]
# Data Sets en análisis
#
# https://www.kaggle.com/datasets/somayehsahebi/super-store dataset número 1
#
# https://www.kaggle.com/datasets/laibaanwer/superstore-sales-dataset dataset número 2
#
# https://www.kaggle.com/datasets/ishanshrivastava28/superstore-sales dataset número 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Observamos cada dataset

# %%
df_1 = pd.read_csv('./dataset1.csv', encoding='utf-8', engine='python')
df_1
# Out:
#            Order_ID  Order_Date   Ship_Date       Ship_Mode      Segment  \
# 0    CA-2016-111682   6/17/2016   6/18/2016     First Class     Consumer
# 1    CA-2017-159954   9/10/2017   9/14/2017  Standard Class     Consumer
# 2    CA-2017-154214   3/20/2017   3/25/2017    Second Class     Consumer
# 3    CA-2017-156391   9/26/2017   9/28/2017     First Class  Home Office
# 4    US-2015-128090   8/16/2015   8/22/2015  Standard Class     Consumer
# ..              ...         ...         ...             ...          ...
# 795  CA-2017-100111   9/20/2017   9/26/2017  Standard Class     Consumer
# 796  US-2017-118087    9/9/2017   9/13/2017  Standard Class    Corporate
# 797  CA-2015-139731  10/15/2015  10/15/2015        Same Day     Consumer
# 798  CA-2014-169019   7/26/2014   7/30/2014  Standard Class     Consumer
# 799  CA-2017-140151   3/23/2017   3/25/2017     First Class     Consumer
#
#            Country           City         State  Postal_Code   Region  ...  \
# ...

# %%
df_2 = pd.read_csv('./dataset2.csv', encoding='utf-8', engine='python')
df_2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df_3 = pd.read_csv('./dataset3.csv', encoding='ISO-8859-1')
df_3
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 1          2  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 2          3  CA-2013-138688  13-06-2013  17-06-2013    Second Class
# 3          4  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# 4          5  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9993    9994  CA-2014-119914  05-05-2014  10-05-2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Comprobamos columnas
#
# Observamos que columnas contiene cada dataset.

# %%
df_1.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Segment',
#        'Country', 'City', 'State', 'Postal_Code', 'Region', 'Product_ID',
#        'Category', 'Sub_Category', 'Product_Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Person', 'Returned', 'total_cost',
#        'price_per_unit'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df_3.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # Comprobamos nulos
#
# Con este comando estamos observando si contenienen nulos, el tipo de dato y también comprobamos la extensión de cada dataset.

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        800 non-null    object
#  1   Order_Date      800 non-null    object
#  2   Ship_Date       800 non-null    object
#  3   Ship_Mode       800 non-null    object
#  4   Segment         800 non-null    object
#  5   Country         800 non-null    object
#  6   City            800 non-null    object
#  7   State           800 non-null    object
#  8   Postal_Code     800 non-null    int64
#  9   Region          800 non-null    object
#  10  Product_ID      800 non-null    object
#  11  Category        800 non-null    object
#  12  Sub_Category    800 non-null    object
#  13  Product_Name    800 non-null    object
#  14  Sales           800 non-null    float64
#  15  Quantity        800 non-null    int64
#  16  Discount        800 non-null    float64
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df_1.shape
# Out:
# (800, 22)

# %%
df_2.shape
# Out:
# (51290, 21)

# %%
df_3.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Columna producto

# %%
df_1['Product_Name']
# Out:
# 0                            Prang Dustless Chalk Sticks
# 1                 Wilson Jones Suede Grain Vinyl Binders
# 2      GE General Purpose, Extra Long Life, Showcase ...
# 3                               Prang Drawing Pencil Set
# 4                                             Newell 346
#                              ...
# 795    Hon 4070 Series Pagoda Armless Upholstered Sta...
# 796                                Samsung Galaxy Note 2
# 797         HON 5400 Series Task Chairs for Big and Tall
# 798            GBC DocuBind P400 Electric Binding System
# 799                Canon imageCLASS 2200 Advanced Copier
# Name: Product_Name, Length: 800, dtype: object

# %%
df_2['product_name']
# Out:
# 0                                    Tenex Lockers, Blue
# 1                               Acme Trimmer, High Speed
# 2                                Tenex Box, Single Width
# 3                            Enermax Note Cards, Premium
# 4                             Eldon Light Bulb, Duo Pack
#                               ...
# 51285    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 51286            Wilson Jones Hole Reinforcements, Clear
# 51287             Hon Color Coded Labels, 5000 Label Set
# 51288             Hon Legal Exhibit Labels, Alphabetical
# 51289                                Bagged Rubber Bands
# Name: product_name, Length: 51290, dtype: object

# %%
df_3['Product Name']
# Out:
# 0                       Bush Somerset Collection Bookcase
# 1       Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2       Self-Adhesive Address Labels for Typewriters b...
# 3           Bretford CR4500 Series Slim Rectangular Table
# 4                          Eldon Fold 'N Roll Cart System
#                               ...
# 9989                               Ultra Door Pull Handle
# 9990    Tenex B1-RE Series Chair Mats for Low Pile Car...
# 9991                                Aastra 57i VoIP phone
# 9992    It's Hot Message Books with Stickers, 2 3/4" x 5"
# 9993    Acco 7-Outlet Masterpiece Power Center, Wihtou...
# Name: Product Name, Length: 9994, dtype: object

# %% [markdown]
# # Dataset1
#
# Vamos a análizar más a fondo el dataset número 1 que coincide más con la temática que queremos aplicar al proyecto.

# %%
df_1.head(20)
# Out:
#           Order_ID  Order_Date   Ship_Date       Ship_Mode      Segment  \
# 0   CA-2016-111682   6/17/2016   6/18/2016     First Class     Consumer
# 1   CA-2017-159954   9/10/2017   9/14/2017  Standard Class     Consumer
# 2   CA-2017-154214   3/20/2017   3/25/2017    Second Class     Consumer
# 3   CA-2017-156391   9/26/2017   9/28/2017     First Class  Home Office
# 4   US-2015-128090   8/16/2015   8/22/2015  Standard Class     Consumer
# 5   CA-2016-145583  10/13/2016  10/19/2016  Standard Class     Consumer
# 6   CA-2014-133690    8/3/2014    8/5/2014     First Class     Consumer
# 7   CA-2015-144267   8/21/2015   8/23/2015     First Class  Home Office
# 8   CA-2016-105291  10/30/2016   11/4/2016  Standard Class     Consumer
# 9   CA-2014-148950  12/14/2014  12/19/2014  Standard Class     Consumer
# 10  CA-2017-100111   9/20/2017   9/26/2017  Standard Class     Consumer
# 11  CA-2016-151372    9/5/2016    9/6/2016     First Class     Consumer
# ...

# %%
df_1.describe().T
# Out:
#                 count          mean           std      min           25%  \
# Postal_Code     800.0  70283.921250  31305.387093  1852.00  43229.000000
# Sales           800.0    225.630375    619.870607     1.68     20.680000
# Quantity        800.0      3.816250      2.230741     1.00      2.000000
# Discount        800.0      0.143425      0.197839     0.00      0.000000
# Profit          800.0     29.040475    295.516983 -3701.89      2.942500
# total_cost      800.0    196.589899    470.164441     0.84     14.602499
# price_per_unit  800.0     73.604849    170.963523     1.14      7.100000
#
#                          50%           75%          max
# Postal_Code     90008.000000  94109.000000  99207.00000
# Sales              59.970000    217.975000  13999.96000
# Quantity            3.000000      5.000000     14.00000
# Discount            0.000000      0.200000      0.80000
# Profit             10.790000     30.610000   6719.98000
# ...

# %%
df_1.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Segment',
#        'Country', 'City', 'State', 'Postal_Code', 'Region', 'Product_ID',
#        'Category', 'Sub_Category', 'Product_Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Person', 'Returned', 'total_cost',
#        'price_per_unit'],
#       dtype='object')

# %%
df_1['Segment']
# Out:
# 0         Consumer
# 1         Consumer
# 2         Consumer
# 3      Home Office
# 4         Consumer
#           ...
# 795       Consumer
# 796      Corporate
# 797       Consumer
# 798       Consumer
# 799       Consumer
# Name: Segment, Length: 800, dtype: object

# %%
df_1['Category']
# Out:
# 0      Office Supplies
# 1      Office Supplies
# 2            Furniture
# 3      Office Supplies
# 4      Office Supplies
#             ...
# 795          Furniture
# 796         Technology
# 797          Furniture
# 798    Office Supplies
# 799         Technology
# Name: Category, Length: 800, dtype: object
