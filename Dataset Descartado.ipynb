# %% [markdown]
# # Importamos librerías
#
# Para este análisis preliminar de datos utilizaremos diversas librerías de Python, que nos van a permitir indagar en el archivo csv que va a funcionar como nuestros datos extraidos del ERP del cliente.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Análisis csv completo
#
# El grueso de nuestros datos se encuentra dentro de df_completo, vamos a observar de cuántas columnas se compone, si tenemos datos nulos, que tipo de datos son, que columnas funcionarán como KPI que guardaremos en en dataframe que servirá de base para nuestra tabla de hechos, cuales pertenecerán a las dimensiones y si debemos prescindir de algún dato.

# %%
df_completo = pd.read_csv('./superstore.csv', encoding='utf-8', engine='python')
df_completo
# Out:
#       Order ID  Order date Order Priority  Order Quantity      Sales  \
# 0            3  27/01/2022            Low               6     261.54
# 1            6  15/09/2021  Not Specified               2       6.93
# 2           32  23/05/2022           High              26    2808.08
# 3           32  31/12/2021           High              24    17610.4
# 4           32  07/10/2021           High              23   1602.335
# ...        ...         ...            ...             ...        ...
# 8394     59971  16/01/2022       Critical              26     437.77
# 8395     59971  07/09/2021       Critical              45     514.86
# 8396     59971  21/01/2021       Critical              12     356.27
# 8397     59973  22/02/2022            Low              30  4.982.944
# 8398     59973  18/09/2021            Low              29   11039.75
#
#            Ship Mode    Profit  Shipping Cost       Customer Name  \
# 0        Regular Air   -213.25          35.00  Muhammed MacIntyre
# ...

# %%
df_completo.columns
# Out:
# Index(['Order ID', 'Order date', 'Order Priority', 'Order Quantity', 'Sales',
#        'Ship Mode', 'Profit', 'Shipping Cost', 'Customer Name',
#        'Customer State', 'Region', 'Customer Segment', 'Product Category',
#        'Product Sub-Category', 'Product Name'],
#       dtype='object')

# %%
df_completo.info
# Out:
# <bound method DataFrame.info of       Order ID  Order date Order Priority  Order Quantity      Sales  \
# 0            3  27/01/2022            Low               6     261.54
# 1            6  15/09/2021  Not Specified               2       6.93
# 2           32  23/05/2022           High              26    2808.08
# 3           32  31/12/2021           High              24    17610.4
# 4           32  07/10/2021           High              23   1602.335
# ...        ...         ...            ...             ...        ...
# 8394     59971  16/01/2022       Critical              26     437.77
# 8395     59971  07/09/2021       Critical              45     514.86
# 8396     59971  21/01/2021       Critical              12     356.27
# 8397     59973  22/02/2022            Low              30  4.982.944
# 8398     59973  18/09/2021            Low              29   11039.75
#
#            Ship Mode    Profit  Shipping Cost       Customer Name  \
# ...

# %%
df_completo.shape
# Out:
# (8399, 15)

# %%
df_completo.head(10)
# Out:
#    Order ID  Order date Order Priority  Order Quantity      Sales  \
# 0         3  27/01/2022            Low               6     261.54
# 1         6  15/09/2021  Not Specified               2       6.93
# 2        32  23/05/2022           High              26    2808.08
# 3        32  31/12/2021           High              24    17610.4
# 4        32  07/10/2021           High              23   1602.335
# 5        32  23/05/2021           High              15     140.56
# 6        35  19/04/2022  Not Specified              30     288.56
# 7        35  15/06/2021  Not Specified              14   1892.848
# 8        36  31/03/2022       Critical              46  24847.455
# 9        65  24/12/2021       Critical              32    3812.73
#
#         Ship Mode    Profit  Shipping Cost       Customer Name Customer State  \
# 0     Regular Air   -213.25          35.00  Muhammed MacIntyre     New Jersey
# 1     Regular Air     -4.64           2.56         Ruben Dartt       New York
# ...

# %%
df_completo['Product Sub-Category']
# Out:
# 0              Storage & Organization
# 1       Scissors, Rulers and Trimmers
# 2                  Office Furnishings
# 3                              Tables
# 4        Telephones and Communication
#                     ...
# 8394             Computer Peripherals
# 8395                            Paper
# 8396                            Paper
# 8397                           Tables
# 8398                  Office Machines
# Name: Product Sub-Category, Length: 8399, dtype: object

# %%
df_completo['Product Category']
# Out:
# 0       Office Supplies
# 1       Office Supplies
# 2             Furniture
# 3             Furniture
# 4            Technology
#              ...
# 8394         Technology
# 8395    Office Supplies
# 8396    Office Supplies
# 8397          Furniture
# 8398         Technology
# Name: Product Category, Length: 8399, dtype: object

# %%
df_completo['Customer Name']
# Out:
# 0       Muhammed MacIntyre
# 1              Ruben Dartt
# 2            Liz Pelletier
# 3            Liz Pelletier
# 4            Liz Pelletier
#                ...
# 8394           Brad Thomas
# 8395           Brad Thomas
# 8396           Brad Thomas
# 8397        Suzanne McNair
# 8398        Suzanne McNair
# Name: Customer Name, Length: 8399, dtype: object

# %%
df_completo.dtypes
# Out:
# Order ID                  int64
# Order date               object
# Order Priority           object
# Order Quantity            int64
# Sales                    object
# Ship Mode                object
# Profit                   object
# Shipping Cost           float64
# Customer Name            object
# Customer State           object
# Region                   object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Name             object
# dtype: object

# %%
df_completo.isnull().sum()
# Out:
# Order ID                0
# Order date              0
# Order Priority          0
# Order Quantity          0
# Sales                   0
# Ship Mode               0
# Profit                  0
# Shipping Cost           0
# Customer Name           0
# Customer State          0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# dtype: int64

# %%
df_completo.describe().T
# Out:
#                  count          mean           std   min      25%       50%  \
# Order ID        8399.0  29965.179783  17260.883447  3.00  15011.5  29857.00
# Order Quantity  8399.0     25.575426     14.482837  1.00     13.0     26.00
# Shipping Cost   8399.0     12.856427     17.318257  0.49      3.3      6.07
#
#                      75%       max
# Order ID        44596.00  59973.00
# Order Quantity     38.00     50.00
# Shipping Cost      13.99    164.73

# %%
df_completo.corr()
# Out:
#                 Order ID  Order Quantity  Shipping Cost
# Order ID        1.000000        0.011461      -0.003857
# Order Quantity  0.011461        1.000000      -0.012162
# Shipping Cost  -0.003857       -0.012162       1.000000

# %% [markdown]
# Hacemos una copia del dataset para asegurarnos el poder recurrir al bruto de los datos si lo necesitamos en algún momento.

# %%
df_completo_copia = df_completo.copy()
df_completo_copia
# Out:
#       Order ID  Order date Order Priority  Order Quantity      Sales  \
# 0            3  27/01/2022            Low               6     261.54
# 1            6  15/09/2021  Not Specified               2       6.93
# 2           32  23/05/2022           High              26    2808.08
# 3           32  31/12/2021           High              24    17610.4
# 4           32  07/10/2021           High              23   1602.335
# ...        ...         ...            ...             ...        ...
# 8394     59971  16/01/2022       Critical              26     437.77
# 8395     59971  07/09/2021       Critical              45     514.86
# 8396     59971  21/01/2021       Critical              12     356.27
# 8397     59973  22/02/2022            Low              30  4.982.944
# 8398     59973  18/09/2021            Low              29   11039.75
#
#            Ship Mode    Profit  Shipping Cost       Customer Name  \
# 0        Regular Air   -213.25          35.00  Muhammed MacIntyre
# ...

# %%
df_dos = pd.read_csv('./SuperStoreOrders.csv', encoding='utf-8', engine='python')
df_dos
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# # Otras exploraciones
#
# Con el fin de utilizar unos datos que satisfagan los requerimientos del proyecto, se analizan otros dataset del mismo estilo.

# %%
df_dos.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')
